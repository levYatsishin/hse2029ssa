# %%
from datetime import datetime

def parse_date(date_str: str, date_format: str) -> datetime | None:
    try:
        return datetime.strptime(date_str, date_format)
    except ValueError:
        return None


# Форматы
date_format_moscow = "%A, %B %d, %Y"
date_format_guardian = "%A, %d.%m.%y"
date_format_daily = "%A, %d %B %Y"

# Строки разных газет
string_moscow = "Wednesday, October 2, 2002"
string_guardian = "Friday, 11.10.13"
string_daily = "Thursday, 18 August 1977"

datetime_moscow = parse_date(s1, date_format_moscow)
datetime_guardian = parse_date(s2, date_format_guardian)
datetime_daily = parse_date(s3, date_format_daily)

print("Moscow:", datetime_moscow)
print("Guardian:", datetime_guardian)
print("Daily News:", datetime_daily)
# Out:
# Moscow: 2002-10-02 00:00:00
# Guardian: 2013-10-11 00:00:00
# Daily News: 1977-08-18 00:00:00
